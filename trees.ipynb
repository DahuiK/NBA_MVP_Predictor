# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# NOTE: This file does Hyperparameter tuning for the different models, to find the most optimal parameters

# Read data from data cleaning
total_data_df = pd.read_csv('output.csv')
# Print the columns
print(total_data_df.columns)

# Select features and target
features =['Age' ,'G', 'GS', 'MP', 'FG', 
           'FG%', '3P', '3P%', 'eFG%', 'ORB', 
           'DRB', 'AST', 'PTS', 'PER', 'FTr', 
           'USG%', 'OWS', 'DWS', 'WS', 'OBPM', 
           'DBPM', 'VORP', 'Tm_Rcrd']
target = 'MVP_Shr'
season_list = [f"{year}_{year + 1 - 2000:02}" for year in range(2000, 2023)]
mse_list = []
r_squared_list = []

def model_testing(model):
    mvp_list = []
    mse_sum = 0
    r_squared_sum = 0
    for season in season_list:
        # Split data into training and testing sets
        X_train = total_data_df[total_data_df['Szn'] != season][features]
        X_test = total_data_df[total_data_df['Szn'] == season][features]
        y_train = total_data_df[total_data_df['Szn'] != season][target]
        y_test = total_data_df[total_data_df['Szn'] == season][target]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # add the top candidates to the prediction
        predictions = pd.DataFrame({'Player': total_data_df[total_data_df['Szn'] == season]['Plyr'], 'Predicted MVP Share': y_pred})
        mvp_list.append(predictions.sort_values(by='Predicted MVP Share', ascending=False) .head(1)['Player'].values[0])         # values[0] is to select the value since dataframes are by default indexed
        
        mse = mean_squared_error(y_test, y_pred)
        r_squared = r2_score(y_test, y_pred)
        mse_sum += mse
        r_squared_sum += r_squared
    
    mse_avg = round(mse_sum / len(season_list), 3)
    r_squared_avg = round(r_squared_sum / len(season_list), 3)

    print('AVG MSE and R-squared:', mse_avg, r_squared_avg)
    mse_list.append(mse_avg)
    r_squared_list.append(r_squared_avg)
    
    return mvp_list
# Out:
# Index(['Plyr', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'id', 'Szn', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'MVP_Rnk', 'MVP_Shr', 'Tm_Rcrd', 'Pos_C', 'Pos_PF', 'Pos_PG',
#        'Pos_SF', 'Pos_SG', 'MVP_strk'],
#       dtype='object')

# %% [markdown]
# ### Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor
results = []
for n in range(150,210,10):
    print(f'Testing Bagging Regressor n_estimators={n}')
    model_result = model_testing(BaggingRegressor(n_estimators=n))
    # append table dataframe to result
    results.append(model_result)

# Make a dataframe, where each column is a model, and each row is a season
results_df_bagging = pd.DataFrame()
mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df_bagging['Truth'] = mvp_winners

for i in range(len(results)):
    results_df_bagging[f'Testing Bagging Regressor n_estimators={50 + i * 10}'] = results[i]

results_df_bagging

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
import numpy as np

results = []

for season in season_list:
    # Split data into training and testing sets
    X_train = total_data_df[total_data_df['Szn'] != season][features]
    X_test = total_data_df[total_data_df['Szn'] == season][features]
    y_train = total_data_df[total_data_df['Szn'] != season][target]
    y_test = total_data_df[total_data_df['Szn'] == season][target]

    rfr = RandomForestRegressor()

    params = {
        'n_estimators': np.arange(50, 110, 50),
        'max_features': np.arange(5, 20, 5)
    }

    grid_search = GridSearchCV(estimator=rfr, param_grid=params, cv=5, n_jobs=-1, verbose=1, scoring='neg_mean_absolute_error', return_train_score=True)
    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    print("Best parameters:", best_params)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 10, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 10, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 10, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 15, 'n_estimators': 50}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters: {'max_features': 10, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestRegressor
results = []
for n in range(50,110,50):
    for i in range(5,20,5):
        print(f'Testing Random Forest Regressor n_estimators={n}, max_features={i}')
        model_result = model_testing(RandomForestRegressor(n_estimators=n, max_features=i))
        # append table dataframe to result
        results.append(model_result)
# Out:
# Testing Random Forest Regressor n_estimators=50, max_features=5
# Testing Random Forest Regressor n_estimators=50, max_features=10
# Testing Random Forest Regressor n_estimators=50, max_features=15
# Testing Random Forest Regressor n_estimators=100, max_features=5
# Testing Random Forest Regressor n_estimators=100, max_features=10
# Testing Random Forest Regressor n_estimators=100, max_features=15

# %%
# Make a dataframe, where each column is a model, and each row is a season
results_df = pd.DataFrame()
mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df['Truth'] = mvp_winners

for i in range(2):
    for j in range(3):
        results_df[f'Testing Random Forest Regressor n_estimators={50 + i * 10}, max_features={(j+1)*5}'] = results[i+j]

results_df
# Out:
#                     Truth  \
# 0           Allen Iverson
# 1              Tim Duncan
# 2              Tim Duncan
# 3           Kevin Garnett
# 4              Steve Nash
# 5              Steve Nash
# 6           Dirk Nowitzki
# 7             Kobe Bryant
# 8            LeBron James
# 9            LeBron James
# 10            Derick Rose
# 11           LeBron James
# 12           LeBron James
# 13           Kevin Durant
# 14          Stephen Curry
# 15          Stephen Curry
# 16      Russell Westbrook
# 17           James Harden
# 18  Giannis Antetokounmpo
# 19  Giannis Antetokounmpo
# 20           Nikola Jokić
# 21           Nikola Jokić
# 22            Joel Embiid
#
#    Testing Random Forest Regressor n_estimators=50, max_features=5  \
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                       Dirk Nowitzki
# 7                                        LeBron James
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                      Stephen Curry
# 15                                      Stephen Curry
# 16                                  Russell Westbrook
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                                       Nikola Jokić
# 22                                       Nikola Jokić
#
#    Testing Random Forest Regressor n_estimators=50, max_features=10  \
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                          Steve Nash
# 7                                        LeBron James
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                       James Harden
# 15                                      Stephen Curry
# 16                                      Kawhi Leonard
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                                       Nikola Jokić
# 22                                       Nikola Jokić
#
#    Testing Random Forest Regressor n_estimators=50, max_features=15  \
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                          Steve Nash
# 7                                          Chris Paul
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                      Stephen Curry
# 15                                      Stephen Curry
# 16                                  Russell Westbrook
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                              Giannis Antetokounmpo
# 22                                       Nikola Jokić
#
#    Testing Random Forest Regressor n_estimators=60, max_features=5  \
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                          Steve Nash
# 7                                        LeBron James
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                       James Harden
# 15                                      Stephen Curry
# 16                                      Kawhi Leonard
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                                       Nikola Jokić
# 22                                       Nikola Jokić
#
#    Testing Random Forest Regressor n_estimators=60, max_features=10  \
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                          Steve Nash
# 7                                          Chris Paul
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                      Stephen Curry
# 15                                      Stephen Curry
# 16                                  Russell Westbrook
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                              Giannis Antetokounmpo
# 22                                       Nikola Jokić
#
#    Testing Random Forest Regressor n_estimators=60, max_features=15
# 0                                    Shaquille O'Neal
# 1                                          Tim Duncan
# 2                                       Tracy McGrady
# 3                                       Kevin Garnett
# 4                                       Kevin Garnett
# 5                                       Dirk Nowitzki
# 6                                          Steve Nash
# 7                                        LeBron James
# 8                                        LeBron James
# 9                                        LeBron James
# 10                                       LeBron James
# 11                                       LeBron James
# 12                                       LeBron James
# 13                                       Kevin Durant
# 14                                      Stephen Curry
# 15                                      Stephen Curry
# 16                                  Russell Westbrook
# 17                                       James Harden
# 18                                       James Harden
# 19                              Giannis Antetokounmpo
# 20                                       Nikola Jokić
# 21                                       Nikola Jokić
# 22                                       Nikola Jokić

# %%
# Accuracy Calculation (correct/23)
for i in range(len(results)):
    correct = 0
    for j in range(len(results[0])):
        if results[i][j] == mvp_winners[j]:
            correct += 1
    print(correct/23)
# Out:
# 0.6521739130434783
# 0.5217391304347826
# 0.5652173913043478
# 0.6086956521739131
# 0.6086956521739131
# 0.5652173913043478

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
results = []
for i in range(5,55,5):
    print(f'Testing Decision Tree Regressor max_depth={i}')
    model_result = model_testing(DecisionTreeRegressor(max_features=i))
    # append table dataframe to result
    results.append(model_result)

# Make a dataframe, where each column is a model, and each row is a season
results_df_decision = pd.DataFrame()

mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df_decision['Truth'] = mvp_winners


for i in range(len(results)):
    results_df_decision[f'Testing Random Forest Regressor max_depth={(i+1)*5}'] = results[i]

results_df_decision
# Out:
# Testing Decision Tree Regressor max_depth=5
# Testing Decision Tree Regressor max_depth=10
# Testing Decision Tree Regressor max_depth=15
# Testing Decision Tree Regressor max_depth=20
# Testing Decision Tree Regressor max_depth=25
# Testing Decision Tree Regressor max_depth=30
# Testing Decision Tree Regressor max_depth=35
# Testing Decision Tree Regressor max_depth=40
# Testing Decision Tree Regressor max_depth=45
# Testing Decision Tree Regressor max_depth=50
#                     Truth Testing Random Forest Regressor max_depth=5  \
# 0           Allen Iverson                               John Stockton
# 1              Tim Duncan                                  Tim Duncan
# 2              Tim Duncan                               Tracy McGrady
# 3           Kevin Garnett                             Jermaine O'Neal
# 4              Steve Nash                           Amar'e Stoudemire
# 5              Steve Nash                                   Ray Allen
# 6           Dirk Nowitzki                                  Steve Nash
# 7             Kobe Bryant                                  Chris Paul
# 8            LeBron James                                 Dwyane Wade
# 9            LeBron James                                LeBron James
# 10            Derick Rose                                LeBron James
# 11           LeBron James                                Kevin Durant
# 12           LeBron James                                Kevin Durant
# 13           Kevin Durant                                Kevin Durant
# 14          Stephen Curry                                James Harden
# 15          Stephen Curry                               Stephen Curry
# 16      Russell Westbrook                               Stephen Curry
# 17           James Harden                       Giannis Antetokounmpo
# 18  Giannis Antetokounmpo                       Giannis Antetokounmpo
# 19  Giannis Antetokounmpo                       Giannis Antetokounmpo
# 20           Nikola Jokić                                Nikola Jokić
# 21           Nikola Jokić                       Giannis Antetokounmpo
# 22            Joel Embiid                                 Joel Embiid
#
#    Testing Random Forest Regressor max_depth=10  \
# 0                                 Allen Iverson
# 1                                    Tim Duncan
# 2                                    Jason Kidd
# 3                                 Kevin Garnett
# 4                                 Tracy McGrady
# 5                              Chauncey Billups
# 6                                  LeBron James
# 7                                    Chris Paul
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                  Dwyane Wade
# 11                                  Dwyane Wade
# 12                                 Kevin Durant
# 13                                 Kevin Durant
# 14                            Russell Westbrook
# 15                                 James Harden
# 16                           Karl-Anthony Towns
# 17                                 James Harden
# 18                        Giannis Antetokounmpo
# 19                        Giannis Antetokounmpo
# 20                                 Nikola Jokić
# 21                        Giannis Antetokounmpo
# 22                        Giannis Antetokounmpo
#
#    Testing Random Forest Regressor max_depth=15  \
# 0                                 John Stockton
# 1                              Shaquille O'Neal
# 2                                 Dirk Nowitzki
# 3                                 Kevin Garnett
# 4                                 Tracy McGrady
# 5                                 Dirk Nowitzki
# 6                                    Steve Nash
# 7                                    Chris Paul
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                 LeBron James
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                Anthony Davis
# 15                                Stephen Curry
# 16                                Kawhi Leonard
# 17                            Russell Westbrook
# 18                                 Nikola Jokić
# 19                        Giannis Antetokounmpo
# 20                            Russell Westbrook
# 21                                 Nikola Jokić
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=20  \
# 0                                 Allen Iverson
# 1                              Shaquille O'Neal
# 2                                    Tim Duncan
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                  LeBron James
# 6                                    Steve Nash
# 7                                    Chris Paul
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                  Dwyane Wade
# 11                                 LeBron James
# 12                                 Kevin Durant
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                                Kawhi Leonard
# 17                                 James Harden
# 18                                 James Harden
# 19                        Giannis Antetokounmpo
# 20                        Giannis Antetokounmpo
# 21                                  Luka Dončić
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=25  \
# 0                                  Chris Webber
# 1                              Shaquille O'Neal
# 2                                    Steve Nash
# 3                                 Kevin Garnett
# 4                             Amar'e Stoudemire
# 5                                 Dirk Nowitzki
# 6                                    Steve Nash
# 7                                Deron Williams
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                 LeBron James
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                            Russell Westbrook
# 17                                 James Harden
# 18                                 James Harden
# 19                        Giannis Antetokounmpo
# 20                        Giannis Antetokounmpo
# 21                                 Nikola Jokić
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=30  \
# 0                                 John Stockton
# 1                              Shaquille O'Neal
# 2                                    Steve Nash
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                 Dirk Nowitzki
# 6                                    Tim Duncan
# 7                                Deron Williams
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                 LeBron James
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                            Russell Westbrook
# 17                                 James Harden
# 18                                 James Harden
# 19                        Giannis Antetokounmpo
# 20                                 Nikola Jokić
# 21                                  Joel Embiid
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=35  \
# 0                                 Allen Iverson
# 1                              Shaquille O'Neal
# 2                                    Tim Duncan
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                 Dirk Nowitzki
# 6                                    Steve Nash
# 7                                Deron Williams
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                 LeBron James
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                            Russell Westbrook
# 17                                 James Harden
# 18                                 James Harden
# 19                                 James Harden
# 20                        Giannis Antetokounmpo
# 21                        Giannis Antetokounmpo
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=40  \
# 0                                 John Stockton
# 1                              Shaquille O'Neal
# 2                                    Steve Nash
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                 Dirk Nowitzki
# 6                                    Steve Nash
# 7                                Deron Williams
# 8                                  LeBron James
# 9                                  LeBron James
# 10                            Russell Westbrook
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                            Russell Westbrook
# 17                                 James Harden
# 18                                 James Harden
# 19                        Giannis Antetokounmpo
# 20                                 Nikola Jokić
# 21                                   Trae Young
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=45  \
# 0                                 John Stockton
# 1                              Shaquille O'Neal
# 2                                    Tim Duncan
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                 Dirk Nowitzki
# 6                                    Steve Nash
# 7                                    Chris Paul
# 8                                  LeBron James
# 9                                  LeBron James
# 10                            Russell Westbrook
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                            Russell Westbrook
# 17                                 James Harden
# 18                                 James Harden
# 19                                Anthony Davis
# 20                                 Nikola Jokić
# 21                                  Luka Dončić
# 22                                 Nikola Jokić
#
#    Testing Random Forest Regressor max_depth=50
# 0                                 John Stockton
# 1                              Shaquille O'Neal
# 2                                    Tim Duncan
# 3                                 Kevin Garnett
# 4                              Shaquille O'Neal
# 5                                 Dirk Nowitzki
# 6                                    Tim Duncan
# 7                                Deron Williams
# 8                                  LeBron James
# 9                                  LeBron James
# 10                                 LeBron James
# 11                                 LeBron James
# 12                                 LeBron James
# 13                                 Kevin Durant
# 14                                 James Harden
# 15                                Stephen Curry
# 16                                 LeBron James
# 17                                 James Harden
# 18                                 James Harden
# 19                        Giannis Antetokounmpo
# 20                        Giannis Antetokounmpo
# 21                                  Luka Dončić
# 22                                 Nikola Jokić

# %%
# Accuracy Calculation (correct/23)
for i in range(len(results)):
    correct = 0
    for j in range(len(results[0])):
        if results[i][j] == mvp_winners[j]:
            correct += 1
    print(correct/23)
# Out:
# 0.34782608695652173
# 0.43478260869565216
# 0.391304347826087
# 0.43478260869565216
# 0.4782608695652174
# 0.4782608695652174
# 0.4782608695652174
# 0.4782608695652174
# 0.4782608695652174
# 0.43478260869565216

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
import numpy as np
results = []
for season in season_list:
    # Split data into training and testing sets
    X_train = total_data_df[total_data_df['Szn'] != season][features]
    X_test = total_data_df[total_data_df['Szn'] == season][features]
    y_train = total_data_df[total_data_df['Szn'] != season][target]
    y_test = total_data_df[total_data_df['Szn'] == season][target]

    gbr = GradientBoostingRegressor()

    params = {
        'max_depth': np.arange(5,30,5),
        'n_estimators': np.arange(50,210,50),
        'learning_rate': np.arange(0.01,0.31,0.1)
    }

    grid_search = GridSearchCV(estimator=gbr, param_grid=params, cv=5, n_jobs=-1, verbose=1, scoring='neg_mean_absolute_error', return_train_score=True)
    grid_search.fit(X_train, y_train)
    # Find best params for each season
    print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 200}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 10, 'n_estimators': 200}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 200}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 150}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 200}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 200}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 150}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 50}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 150}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 150}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.11, 'max_depth': 5, 'n_estimators': 100}
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'learning_rate': 0.21000000000000002, 'max_depth': 5, 'n_estimators': 150}

# %%
# Apply the parameters that appeared most frequently above

# append table dataframe to result
for n in range(50,210,50):
    for i in range(3):
        print(f'Testing Gradient Boosting Regressor learning_rate: {0.01+i*0.1}, max_depth: 5, n_estimators: {n}')
        model_result = model_testing(GradientBoostingRegressor(max_depth=5, learning_rate=0.01+i*0.1, n_estimators=n))
        # append table dataframe to result
        results.append(model_result)

# Make a dataframe, where each column is a model, and each row is a season
results_df_gbr = pd.DataFrame()
mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df_gbr['Truth'] = mvp_winners
for i in range(len(results)):
    results_df_gbr[f'Gradient Boosting Regressor {i}'] = results[i]
    
results_df_gbr
# Out:
# Testing Gradient Boosting Regressor learning_rate: 0.01, max_depth: 5, n_estimators: 50
# Testing Gradient Boosting Regressor learning_rate: 0.11, max_depth: 5, n_estimators: 50
# Testing Gradient Boosting Regressor learning_rate: 0.21000000000000002, max_depth: 5, n_estimators: 50
# Testing Gradient Boosting Regressor learning_rate: 0.01, max_depth: 5, n_estimators: 100
# Testing Gradient Boosting Regressor learning_rate: 0.11, max_depth: 5, n_estimators: 100
# Testing Gradient Boosting Regressor learning_rate: 0.21000000000000002, max_depth: 5, n_estimators: 100
# Testing Gradient Boosting Regressor learning_rate: 0.01, max_depth: 5, n_estimators: 150
# Testing Gradient Boosting Regressor learning_rate: 0.11, max_depth: 5, n_estimators: 150
# Testing Gradient Boosting Regressor learning_rate: 0.21000000000000002, max_depth: 5, n_estimators: 150
# Testing Gradient Boosting Regressor learning_rate: 0.01, max_depth: 5, n_estimators: 200
# Testing Gradient Boosting Regressor learning_rate: 0.11, max_depth: 5, n_estimators: 200
# Testing Gradient Boosting Regressor learning_rate: 0.21000000000000002, max_depth: 5, n_estimators: 200
#                     Truth Gradient Boosting Regressor 0  \
# 0           Allen Iverson              Shaquille O'Neal
# 1              Tim Duncan              Shaquille O'Neal
# 2              Tim Duncan                    Tim Duncan
# 3           Kevin Garnett                 Kevin Garnett
# 4              Steve Nash                 Tracy McGrady
# 5              Steve Nash                  LeBron James
# 6           Dirk Nowitzki                  LeBron James
# 7             Kobe Bryant                    Chris Paul
# 8            LeBron James                  LeBron James
# 9            LeBron James                  LeBron James
# 10            Derick Rose                  LeBron James
# 11           LeBron James                  LeBron James
# 12           LeBron James                  LeBron James
# 13           Kevin Durant                  LeBron James
# 14          Stephen Curry                  James Harden
# 15          Stephen Curry                 Stephen Curry
# 16      Russell Westbrook             Russell Westbrook
# 17           James Harden                  James Harden
# 18  Giannis Antetokounmpo         Giannis Antetokounmpo
# 19  Giannis Antetokounmpo         Giannis Antetokounmpo
# 20           Nikola Jokić                  Nikola Jokić
# 21           Nikola Jokić         Giannis Antetokounmpo
# 22            Joel Embiid                  Nikola Jokić
#
#    Gradient Boosting Regressor 1 Gradient Boosting Regressor 2  \
# 0               Shaquille O'Neal              Shaquille O'Neal
# 1               Shaquille O'Neal              Shaquille O'Neal
# 2                     Tim Duncan                    Tim Duncan
# 3                  Kevin Garnett                 Kevin Garnett
# 4                  Tracy McGrady                 Kevin Garnett
# 5                   LeBron James                 Dirk Nowitzki
# 6                   LeBron James                    Steve Nash
# 7                     Chris Paul                    Chris Paul
# 8                   LeBron James                  LeBron James
# 9                   LeBron James                  LeBron James
# 10                  LeBron James                  LeBron James
# 11                  LeBron James                  LeBron James
# 12                  LeBron James                  LeBron James
# 13                  LeBron James                  Kevin Durant
# 14                  James Harden                 Stephen Curry
# 15                 Stephen Curry                 Stephen Curry
# 16             Russell Westbrook             Russell Westbrook
# 17                  James Harden                  James Harden
# 18         Giannis Antetokounmpo                  James Harden
# 19         Giannis Antetokounmpo         Giannis Antetokounmpo
# 20                  Nikola Jokić                  Nikola Jokić
# 21         Giannis Antetokounmpo                   Joel Embiid
# 22                  Nikola Jokić                  Nikola Jokić
#
#    Gradient Boosting Regressor 3 Gradient Boosting Regressor 4  \
# 0               Shaquille O'Neal              Shaquille O'Neal
# 1               Shaquille O'Neal              Shaquille O'Neal
# 2                    Kobe Bryant                    Tim Duncan
# 3                  Kevin Garnett                 Kevin Garnett
# 4                  Kevin Garnett                 Tracy McGrady
# 5                  Dirk Nowitzki                 Dirk Nowitzki
# 6                     Steve Nash                    Tim Duncan
# 7                     Chris Paul                    Chris Paul
# 8                   LeBron James                  LeBron James
# 9                   LeBron James                  LeBron James
# 10                  LeBron James                  LeBron James
# 11                  LeBron James                  LeBron James
# 12                  LeBron James                  LeBron James
# 13                  Kevin Durant                  LeBron James
# 14                 Stephen Curry                  James Harden
# 15                 Stephen Curry                 Stephen Curry
# 16             Russell Westbrook             Russell Westbrook
# 17                  James Harden                  James Harden
# 18                  James Harden                  James Harden
# 19         Giannis Antetokounmpo         Giannis Antetokounmpo
# 20                  Nikola Jokić                  Nikola Jokić
# 21         Giannis Antetokounmpo         Giannis Antetokounmpo
# 22                  Nikola Jokić                  Nikola Jokić
#
#    Gradient Boosting Regressor 5 Gradient Boosting Regressor 6  \
# 0               Shaquille O'Neal              Shaquille O'Neal
# 1               Shaquille O'Neal                    Tim Duncan
# 2                     Tim Duncan                   Kobe Bryant
# 3                  Kevin Garnett                 Kevin Garnett
# 4                  Kevin Garnett                 Dirk Nowitzki
# 5                  Dirk Nowitzki                 Dirk Nowitzki
# 6                     Steve Nash                    Steve Nash
# 7                     Chris Paul                    Chris Paul
# 8                   LeBron James                  LeBron James
# 9                   LeBron James                  LeBron James
# 10                  LeBron James                  LeBron James
# 11                  LeBron James                  LeBron James
# 12                  LeBron James                  LeBron James
# 13                  Kevin Durant                  Kevin Durant
# 14                 Stephen Curry                 Stephen Curry
# 15                 Stephen Curry                 Stephen Curry
# 16             Russell Westbrook             Russell Westbrook
# 17                  James Harden                  James Harden
# 18                  James Harden                  James Harden
# 19         Giannis Antetokounmpo         Giannis Antetokounmpo
# 20                  Nikola Jokić                  Nikola Jokić
# 21                   Joel Embiid         Giannis Antetokounmpo
# 22                  Nikola Jokić                  Nikola Jokić
#
#    Gradient Boosting Regressor 7 Gradient Boosting Regressor 8  ...  \
# 0               Shaquille O'Neal              Shaquille O'Neal  ...
# 1               Shaquille O'Neal              Shaquille O'Neal  ...
# 2                     Tim Duncan                    Tim Duncan  ...
# 3                  Kevin Garnett                 Kevin Garnett  ...
# 4                  Kevin Garnett                 Kevin Garnett  ...
# 5                  Dirk Nowitzki                 Dirk Nowitzki  ...
# 6                     Steve Nash                    Steve Nash  ...
# 7                     Chris Paul                    Chris Paul  ...
# 8                   LeBron James                  LeBron James  ...
# 9                   LeBron James                  LeBron James  ...
# 10                  LeBron James                  LeBron James  ...
# 11                  LeBron James                  LeBron James  ...
# 12                  LeBron James                  LeBron James  ...
# 13                  LeBron James                  Kevin Durant  ...
# 14                 Stephen Curry                 Stephen Curry  ...
# 15                 Stephen Curry                 Stephen Curry  ...
# 16             Russell Westbrook             Russell Westbrook  ...
# 17                  James Harden                  James Harden  ...
# 18                  James Harden                  James Harden  ...
# 19         Giannis Antetokounmpo         Giannis Antetokounmpo  ...
# 20                  Nikola Jokić                  Nikola Jokić  ...
# 21         Giannis Antetokounmpo         Giannis Antetokounmpo  ...
# 22                  Nikola Jokić                  Nikola Jokić  ...
#
#    Gradient Boosting Regressor 15 Gradient Boosting Regressor 16  \
# 0                Shaquille O'Neal               Shaquille O'Neal
# 1                Shaquille O'Neal               Shaquille O'Neal
# 2                   Tracy McGrady                     Tim Duncan
# 3                   Kevin Garnett                  Kevin Garnett
# 4                 Stephon Marbury                  Tracy McGrady
# 5                   Dirk Nowitzki                  Dirk Nowitzki
# 6                      Steve Nash                     Tim Duncan
# 7                      Chris Paul                     Chris Paul
# 8                    LeBron James                   LeBron James
# 9                    LeBron James                   LeBron James
# 10                   LeBron James                   LeBron James
# 11                   LeBron James                   LeBron James
# 12                   LeBron James                   LeBron James
# 13                   Kevin Durant                   LeBron James
# 14                  Stephen Curry                   James Harden
# 15                  Stephen Curry                  Stephen Curry
# 16              Russell Westbrook              Russell Westbrook
# 17                   James Harden                   James Harden
# 18                   James Harden                   James Harden
# 19          Giannis Antetokounmpo          Giannis Antetokounmpo
# 20                   Nikola Jokić                   Nikola Jokić
# 21          Giannis Antetokounmpo          Giannis Antetokounmpo
# 22                   Nikola Jokić                   Nikola Jokić
#
#    Gradient Boosting Regressor 17 Gradient Boosting Regressor 18  \
# 0                Shaquille O'Neal               Shaquille O'Neal
# 1                Shaquille O'Neal                     Tim Duncan
# 2                      Tim Duncan                    Kobe Bryant
# 3                   Kevin Garnett                  Kevin Garnett
# 4                   Kevin Garnett                Stephon Marbury
# 5                   Dirk Nowitzki                  Dirk Nowitzki
# 6                      Steve Nash                     Steve Nash
# 7                      Chris Paul                     Chris Paul
# 8                    LeBron James                   LeBron James
# 9                    LeBron James                   LeBron James
# 10                   LeBron James                   LeBron James
# 11                   LeBron James                   LeBron James
# 12                   LeBron James                   LeBron James
# 13                   Kevin Durant                   Kevin Durant
# 14                  Stephen Curry                  Stephen Curry
# 15                  Stephen Curry                  Stephen Curry
# 16              Russell Westbrook              Russell Westbrook
# 17                   James Harden                   James Harden
# 18                   James Harden                   James Harden
# 19          Giannis Antetokounmpo          Giannis Antetokounmpo
# 20                   Nikola Jokić                   Nikola Jokić
# 21                    Joel Embiid          Giannis Antetokounmpo
# 22                   Nikola Jokić                   Nikola Jokić
#
#    Gradient Boosting Regressor 19 Gradient Boosting Regressor 20  \
# 0                Shaquille O'Neal               Shaquille O'Neal
# 1                Shaquille O'Neal               Shaquille O'Neal
# 2                     Kobe Bryant                     Tim Duncan
# 3                   Kevin Garnett                  Kevin Garnett
# 4                   Kevin Garnett                  Kevin Garnett
# 5                   Dirk Nowitzki                  Dirk Nowitzki
# 6                      Steve Nash                     Steve Nash
# 7                      Chris Paul                     Chris Paul
# 8                    LeBron James                   LeBron James
# 9                    LeBron James                   LeBron James
# 10                   LeBron James                   LeBron James
# 11                   LeBron James                   LeBron James
# 12                   LeBron James                   LeBron James
# 13                   Kevin Durant                   Kevin Durant
# 14                  Stephen Curry                  Stephen Curry
# 15                  Stephen Curry                  Stephen Curry
# 16              Russell Westbrook              Russell Westbrook
# 17                   James Harden                   James Harden
# 18                   James Harden                   James Harden
# 19          Giannis Antetokounmpo          Giannis Antetokounmpo
# 20                   Nikola Jokić                   Nikola Jokić
# 21          Giannis Antetokounmpo          Giannis Antetokounmpo
# 22                   Nikola Jokić                   Nikola Jokić
#
#    Gradient Boosting Regressor 21 Gradient Boosting Regressor 22  \
# 0                Shaquille O'Neal               Shaquille O'Neal
# 1                Shaquille O'Neal               Shaquille O'Neal
# 2                     Kobe Bryant                    Kobe Bryant
# 3                   Kevin Garnett                  Kevin Garnett
# 4                   Kevin Garnett                  Kevin Garnett
# 5                   Dirk Nowitzki                  Dirk Nowitzki
# 6                      Steve Nash                     Steve Nash
# 7                      Chris Paul                     Chris Paul
# 8                    LeBron James                   LeBron James
# 9                    LeBron James                   LeBron James
# 10                   LeBron James                   LeBron James
# 11                   LeBron James                   LeBron James
# 12                   LeBron James                   LeBron James
# 13                   Kevin Durant                   Kevin Durant
# 14                  Stephen Curry                  Stephen Curry
# 15                  Stephen Curry                  Stephen Curry
# 16              Russell Westbrook              Russell Westbrook
# 17                   James Harden                   James Harden
# 18                   James Harden                   James Harden
# 19          Giannis Antetokounmpo          Giannis Antetokounmpo
# 20                   Nikola Jokić                   Nikola Jokić
# 21          Giannis Antetokounmpo          Giannis Antetokounmpo
# 22                   Nikola Jokić                   Nikola Jokić
#
#    Gradient Boosting Regressor 23 Gradient Boosting Regressor 24
# 0                Shaquille O'Neal               Shaquille O'Neal
# 1                Shaquille O'Neal                     Tim Duncan
# 2                      Tim Duncan                  Tracy McGrady
# 3                   Kevin Garnett                  Kevin Garnett
# 4                   Kevin Garnett                  Kevin Garnett
# 5                   Dirk Nowitzki                  Dirk Nowitzki
# 6                      Steve Nash                     Steve Nash
# 7                      Chris Paul                     Chris Paul
# 8                    LeBron James                   LeBron James
# 9                    LeBron James                   LeBron James
# 10                   LeBron James                   LeBron James
# 11                   LeBron James                   LeBron James
# 12                   LeBron James                   LeBron James
# 13                   Kevin Durant                   Kevin Durant
# 14                  Stephen Curry                  Stephen Curry
# 15                  Stephen Curry                  Stephen Curry
# 16              Russell Westbrook              Russell Westbrook
# 17                   James Harden                   James Harden
# 18                   James Harden                   James Harden
# 19          Giannis Antetokounmpo          Giannis Antetokounmpo
# 20                   Nikola Jokić                   Nikola Jokić
# 21          Giannis Antetokounmpo          Giannis Antetokounmpo
# 22                   Nikola Jokić                   Nikola Jokić
#
# [23 rows x 26 columns]

# %%
# Accuracy Calculation (correct/23)
for i in range(len(results)):
    correct = 0
    for j in range(len(results[0])):
        if results[i][j] == mvp_winners[j]:
            correct += 1
    print(correct/23)

# %% [markdown]
# ### AdaBoost Regresssion

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
results = []
for season in season_list:
    # Split data into training and testing sets
    X_train = total_data_df[total_data_df['Szn'] != season][features]
    X_test = total_data_df[total_data_df['Szn'] == season][features]
    y_train = total_data_df[total_data_df['Szn'] != season][target]
    y_test = total_data_df[total_data_df['Szn'] == season][target]

    ada = AdaBoostRegressor()

    params = {
        'n_estimators': np.arange(50,160,50),
        'learning_rate': np.arange(0.5,1.1,0.1)
    }

    grid_search = GridSearchCV(estimator=ada, param_grid=params, cv=5, n_jobs=-1, verbose=1, scoring='neg_mean_absolute_error', return_train_score=True)
    grid_search.fit(X_train, y_train)
    # Find best params for each season
    print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.6, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# {'learning_rate': 0.5, 'n_estimators': 50}

# %%
# Apply the parameters that appeared most frequently above
print('Testing AdaBoost Regressor learning_rate: 0.5, n_estimators: 50')
model_result = model_testing(AdaBoostRegressor(learning_rate= 0.5, n_estimators=50))
# append table dataframe to result
results.append(model_result)

# Make a dataframe, where each column is a model, and each row is a season
results_df_ada = pd.DataFrame()
mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df_ada['Truth'] = mvp_winners
results_df_ada['AdaBoost Regressor'] = results[0]
results_df_ada
# Out:
# Testing AdaBoost Regressor learning_rate: 0.5, n_estimators: 50
#                     Truth     AdaBoost Regressor
# 0           Allen Iverson       Shaquille O'Neal
# 1              Tim Duncan             Tim Duncan
# 2              Tim Duncan             Tim Duncan
# 3           Kevin Garnett          Kevin Garnett
# 4              Steve Nash          Kevin Garnett
# 5              Steve Nash          Dirk Nowitzki
# 6           Dirk Nowitzki             Steve Nash
# 7             Kobe Bryant             Chris Paul
# 8            LeBron James           LeBron James
# 9            LeBron James           LeBron James
# 10            Derick Rose           LeBron James
# 11           LeBron James           LeBron James
# 12           LeBron James           LeBron James
# 13           Kevin Durant           Kevin Durant
# 14          Stephen Curry          Stephen Curry
# 15          Stephen Curry          Stephen Curry
# 16      Russell Westbrook          Kawhi Leonard
# 17           James Harden           James Harden
# 18  Giannis Antetokounmpo  Giannis Antetokounmpo
# 19  Giannis Antetokounmpo  Giannis Antetokounmpo
# 20           Nikola Jokić           Nikola Jokić
# 21           Nikola Jokić  Giannis Antetokounmpo
# 22            Joel Embiid           Nikola Jokić

# %%
# Accuracy Calculation (correct/23)
for i in range(len(results)):
    correct = 0
    for j in range(len(results[0])):
        if results[i][j] == mvp_winners[j]:
            correct += 1
    print(correct/23)
# Out:
# 0.6086956521739131

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVR

results = []
C = [0.001,0.01,0.1,0.5,1,2,5,10]
    
for c in C:
    print(f'Testing SVM with kernel=kbf C={c}')
    model_result = model_testing(SVR(C=c))
    # append table dataframe to result
    results.append(model_result)

# Make a dataframe, where each column is a model, and each row is a season
results_df_svm = pd.DataFrame()
mvp_winners = ['Allen Iverson', 'Tim Duncan', 'Tim Duncan', 'Kevin Garnett', 'Steve Nash', 
               'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James', 'LeBron James', 
               'Derick Rose', 'LeBron James', 'LeBron James', 'Kevin Durant', 'Stephen Curry', 
               'Stephen Curry', 'Russell Westbrook', 'James Harden', 'Giannis Antetokounmpo', 
               'Giannis Antetokounmpo', 'Nikola Jokić', 'Nikola Jokić', 'Joel Embiid']
results_df_svm['Truth'] = mvp_winners

for i in range(len(results)):
    results_df_svm[f'SVM with C={C[i]}'] = results[i]

results_df_svm
# Out:
# Testing SVM with kernel=kbf C=0.001
# AVG MSE and R-squared: 0.026 -0.163
# Testing SVM with kernel=kbf C=0.01
# AVG MSE and R-squared: 0.023 -0.042
# Testing SVM with kernel=kbf C=0.1
# AVG MSE and R-squared: 0.014 0.341
# Testing SVM with kernel=kbf C=0.5
# AVG MSE and R-squared: 0.013 0.42
# Testing SVM with kernel=kbf C=1
# AVG MSE and R-squared: 0.012 0.461
# Testing SVM with kernel=kbf C=2
# AVG MSE and R-squared: 0.01 0.519
# Testing SVM with kernel=kbf C=5
# AVG MSE and R-squared: 0.01 0.542
# Testing SVM with kernel=kbf C=10
# AVG MSE and R-squared: 0.009 0.56
#                     Truth       SVM with C=0.001        SVM with C=0.01  \
# 0           Allen Iverson       Shaquille O'Neal       Shaquille O'Neal
# 1              Tim Duncan             Tim Duncan             Tim Duncan
# 2              Tim Duncan          Tracy McGrady             Tim Duncan
# 3           Kevin Garnett          Kevin Garnett          Kevin Garnett
# 4              Steve Nash          Dirk Nowitzki          Dirk Nowitzki
# 5              Steve Nash          Dirk Nowitzki          Dirk Nowitzki
# 6           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 7             Kobe Bryant           LeBron James           LeBron James
# 8            LeBron James           LeBron James           LeBron James
# 9            LeBron James           LeBron James           LeBron James
# 10            Derick Rose           LeBron James           LeBron James
# 11           LeBron James           LeBron James           LeBron James
# 12           LeBron James           LeBron James           LeBron James
# 13           Kevin Durant           Kevin Durant           Kevin Durant
# 14          Stephen Curry          Stephen Curry          Stephen Curry
# 15          Stephen Curry          Stephen Curry          Stephen Curry
# 16      Russell Westbrook      Russell Westbrook      Russell Westbrook
# 17           James Harden           James Harden           James Harden
# 18  Giannis Antetokounmpo           James Harden           James Harden
# 19  Giannis Antetokounmpo  Giannis Antetokounmpo  Giannis Antetokounmpo
# 20           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 21           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 22            Joel Embiid            Joel Embiid            Joel Embiid
#
#            SVM with C=0.1         SVM with C=0.5           SVM with C=1  \
# 0        Shaquille O'Neal       Shaquille O'Neal       Shaquille O'Neal
# 1              Tim Duncan             Tim Duncan             Tim Duncan
# 2           Tracy McGrady             Tim Duncan             Tim Duncan
# 3           Kevin Garnett          Kevin Garnett          Kevin Garnett
# 4           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 5           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 6           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 7            LeBron James           LeBron James             Chris Paul
# 8            LeBron James           LeBron James           LeBron James
# 9            LeBron James           LeBron James           LeBron James
# 10           LeBron James           LeBron James           LeBron James
# 11           LeBron James           LeBron James           LeBron James
# 12           LeBron James           LeBron James           LeBron James
# 13           Kevin Durant           Kevin Durant           Kevin Durant
# 14          Stephen Curry          Stephen Curry          Stephen Curry
# 15          Stephen Curry          Stephen Curry          Stephen Curry
# 16      Russell Westbrook      Russell Westbrook      Russell Westbrook
# 17           James Harden           James Harden           James Harden
# 18           James Harden           James Harden           James Harden
# 19  Giannis Antetokounmpo  Giannis Antetokounmpo  Giannis Antetokounmpo
# 20           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 21           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 22            Joel Embiid            Joel Embiid            Joel Embiid
#
#              SVM with C=2           SVM with C=5          SVM with C=10
# 0        Shaquille O'Neal       Shaquille O'Neal       Shaquille O'Neal
# 1              Tim Duncan             Tim Duncan             Tim Duncan
# 2              Tim Duncan             Tim Duncan             Tim Duncan
# 3           Kevin Garnett          Kevin Garnett          Kevin Garnett
# 4           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 5           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 6           Dirk Nowitzki          Dirk Nowitzki          Dirk Nowitzki
# 7              Chris Paul             Chris Paul             Chris Paul
# 8            LeBron James           LeBron James           LeBron James
# 9            LeBron James           LeBron James           LeBron James
# 10           LeBron James           LeBron James           LeBron James
# 11           LeBron James           LeBron James           LeBron James
# 12           LeBron James           LeBron James           LeBron James
# 13           Kevin Durant           Kevin Durant           Kevin Durant
# 14          Stephen Curry          Stephen Curry          Stephen Curry
# 15          Stephen Curry          Stephen Curry          Stephen Curry
# 16      Russell Westbrook      Russell Westbrook      Russell Westbrook
# 17           James Harden           James Harden           James Harden
# 18           James Harden           James Harden           James Harden
# 19  Giannis Antetokounmpo  Giannis Antetokounmpo  Giannis Antetokounmpo
# 20           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 21           Nikola Jokić           Nikola Jokić           Nikola Jokić
# 22            Joel Embiid            Joel Embiid            Joel Embiid

# %%
# Accuracy Calculation (correct/23)
final_metrics = pd.DataFrame()

for i in range(len(results)):
    correct = 0
    for j in range(len(results[0])):
        if results[i][j] == mvp_winners[j]:
            correct += 1
            
    metrics = {'C': [C[i]],
               'MSE': [mse_list[i]],
               'R2': [r_squared_list[i]],
                'Accuracy': [round((correct / 23), 3)]}
    
    model_data = pd.DataFrame(data=metrics)
    final_metrics = pd.concat([final_metrics, model_data], ignore_index=True)

final_metrics
# Out:
#         C    MSE     R2  Accuracy
# 0   0.001  0.026 -0.163     0.696
# 1   0.010  0.023 -0.042     0.739
# 2   0.100  0.014  0.341     0.696
# 3   0.500  0.013  0.420     0.739
# 4   1.000  0.012  0.461     0.739
# 5   2.000  0.010  0.519     0.739
# 6   5.000  0.010  0.542     0.739
# 7  10.000  0.009  0.560     0.739
